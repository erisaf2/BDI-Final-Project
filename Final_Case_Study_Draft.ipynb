# %% [markdown]
# <a href="https://colab.research.google.com/github/erisaf2/BDI-Final-Project/blob/main/Final_Case_Study_Draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# I chose the COVID-19 Dataset in order to compare COVID cases at the height of the Pandemic in the US on Jan 8, 2021 versus April 30, 2021. I'm curious to see how the US has improved after the vaccine has been rolled out and fully administered to over 30% of the population, as of May 2, 2021. This data includes the 50 states, US Territories and two cruise ships that had the initial large COVID outbreaks, Diamond Princess and Grand Princess.

# %% [markdown]
# Some questions I have when looking at these datasets include:
# 1. States/Territories with the most vs. least cases
# 2. States/Territories with the most vs. least deaths
# 3. How cases have ranged as a whole over the last ~4 months
# 4. Cases in the US shown geographically
# 5. Fatality rate by State/Territory
# 5. Top 10 highest death rate
# 6. Bottom 10 lowest confirmed case rate

# %%
import pandas as pd
import numpy as np
import plotly
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio

# %%
#height of COVID-19 Pandemic in US
df1 = pd.read_csv('https://github.com/erisaf2/BDI-Final-Project/raw/main/01-08-2021.csv')

# %%
#Pandemic today after vaccine rollout
df2 = pd.read_csv('https://github.com/erisaf2/BDI-Final-Project/raw/main/04-30-2021.csv')

# %%
df1.shape
# Out:
# (58, 18)

# %%
df2.shape
# Out:
# (58, 18)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        58 non-null     object
#  1   Country_Region        58 non-null     object
#  2   Last_Update           58 non-null     object
#  3   Lat                   56 non-null     float64
#  4   Long_                 56 non-null     float64
#  5   Confirmed             58 non-null     int64
#  6   Deaths                58 non-null     int64
#  7   Recovered             48 non-null     float64
#  8   Active                58 non-null     float64
#  9   FIPS                  58 non-null     float64
#  10  Incident_Rate         56 non-null     float64
#  11  Total_Test_Results    56 non-null     float64
#  12  People_Hospitalized   0 non-null      float64
#  13  Case_Fatality_Ratio   57 non-null     float64
#  14  UID                   58 non-null     float64
#  15  ISO3                  58 non-null     object
#  16  Testing_Rate          56 non-null     float64
#  17  Hospitalization_Rate  0 non-null      float64
# dtypes: float64(12), int64(2), object(4)
# memory usage: 8.3+ KB

# %%
#Cleaning the df1 data to remove columns with missing values
df1.drop(columns=['People_Hospitalized','Hospitalization_Rate'], inplace=True)

# %%
df1.head(3)
# Out:
#    Province_State Country_Region  ... ISO3   Testing_Rate
# 0         Alabama             US  ...  USA   39652.450397
# 1          Alaska             US  ...  USA  182866.262499
# 2  American Samoa             US  ...  ASM    3846.084722
#
# [3 rows x 16 columns]

# %%
df1.sample(5)
# Out:
#       Province_State Country_Region  ... ISO3  Testing_Rate
# 37    North Carolina             US  ...  USA  70618.713580
# 21          Kentucky             US  ...  USA  73870.558566
# 33     New Hampshire             US  ...  USA  79857.337331
# 44       Puerto Rico             US  ...  PRI  12150.162163
# 9   Diamond Princess             US  ...  USA           NaN
#
# [5 rows x 16 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        58 non-null     object
#  1   Country_Region        58 non-null     object
#  2   Last_Update           58 non-null     object
#  3   Lat                   56 non-null     float64
#  4   Long_                 56 non-null     float64
#  5   Confirmed             58 non-null     int64
#  6   Deaths                58 non-null     int64
#  7   Recovered             0 non-null      float64
#  8   Active                0 non-null      float64
#  9   FIPS                  58 non-null     float64
#  10  Incident_Rate         56 non-null     float64
#  11  Total_Test_Results    56 non-null     float64
#  12  People_Hospitalized   0 non-null      float64
#  13  Case_Fatality_Ratio   57 non-null     float64
#  14  UID                   58 non-null     float64
#  15  ISO3                  58 non-null     object
#  16  Testing_Rate          56 non-null     float64
#  17  Hospitalization_Rate  0 non-null      float64
# dtypes: float64(12), int64(2), object(4)
# memory usage: 8.3+ KB

# %%
#Cleaning the df2 data to remove columns with missing values
df2.drop(columns=['Recovered','Active','People_Hospitalized','Hospitalization_Rate'], inplace=True)

# %%
df2.head(3)
# Out:
#    Province_State Country_Region  ... ISO3   Testing_Rate
# 0         Alabama             US  ...  USA   50963.241240
# 1          Alaska             US  ...  USA  285881.524718
# 2  American Samoa             US  ...  ASM    3846.084722
#
# [3 rows x 14 columns]

# %%
df2.sample(5)
# Out:
#           Province_State Country_Region  ... ISO3   Testing_Rate
# 31              Nebraska             US  ...  USA  146655.669331
# 38          North Dakota             US  ...  USA  199381.021492
# 32                Nevada             US  ...  USA  103087.181299
# 10  District of Columbia             US  ...  USA  215317.485395
# 0                Alabama             US  ...  USA   50963.241240
#
# [5 rows x 14 columns]

# %%
#Top 5 States/Territories with most confirmed cases on Jan 8 2021
df1_sorted_by_cases = df1.sort_values('Confirmed', ascending=False)
df1_sorted_by_cases.head(5)
# Out:
#    Province_State Country_Region  ... ISO3   Testing_Rate
# 5      California             US  ...  USA   88649.352885
# 49          Texas             US  ...  USA   50120.025668
# 11        Florida             US  ...  USA   77256.169959
# 36       New York             US  ...  USA  137846.921702
# 17       Illinois             US  ...  USA  109870.641323
#
# [5 rows x 16 columns]

# %%
#Top 5 States/Territories with most confirmed cases on May 2 2021
df2_sorted_by_cases = df2.sort_values('Confirmed', ascending=False)
df2_sorted_by_cases.head(5)
# Out:
#    Province_State Country_Region  ... ISO3   Testing_Rate
# 5      California             US  ...  USA  151333.416497
# 49          Texas             US  ...  USA   79327.887985
# 11        Florida             US  ...  USA  105307.160619
# 36       New York             US  ...  USA  262118.174662
# 17       Illinois             US  ...  USA  178019.165517
#
# [5 rows x 14 columns]

# %%
#Top 3 States/Territories with most overall deaths on Jan 8 2021
df1_sorted_by_deaths = df1.sort_values('Deaths', ascending=False)
df1_sorted_by_deaths.head(3)
# Out:
#    Province_State Country_Region  ... ISO3   Testing_Rate
# 36       New York             US  ...  USA  137846.921702
# 49          Texas             US  ...  USA   50120.025668
# 5      California             US  ...  USA   88649.352885
#
# [3 rows x 16 columns]

# %%
#Top 3 States/Territories with most overall deaths on May 2 2021
df2_sorted_by_deaths = df2.sort_values('Deaths', ascending=False)
df2_sorted_by_deaths.head(3)
# Out:
#    Province_State Country_Region  ... ISO3   Testing_Rate
# 5      California             US  ...  USA  151333.416497
# 36       New York             US  ...  USA  262118.174662
# 49          Texas             US  ...  USA   79327.887985
#
# [3 rows x 14 columns]

# %%
#Grouping by Case Fatality Ratio and Deaths - this shows the top 5 fatality ratios and 
#how many deaths occurred in these states/territories
df1_fatality_by_cases = df1.groupby('Case_Fatality_Ratio', as_index=False).agg({'Deaths': ['sum']})
df1_fatality_by_cases.tail(5)
# Out:
#    Case_Fatality_Ratio Deaths
#                           sum
# 52            2.912621      3
# 53            3.069992   6324
# 54            3.093722  12985
# 55            3.566406  39282
# 56            3.824176  19756

# %%
fig1 = px.box(df1[df1['Confirmed']<1000000],
             x='Confirmed',
             orientation='h',
             title='Confirmed Cases (for areas with less than 1mil cases) as of Jan 8 2021')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6e6cc05f-0d86-4d01-887c-8c0f7a33d7a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6e6cc05f-0d86-4d01-887c-8c0f7a33d7a3")) {
#                     Plotly.newPlot(
#                         '6e6cc05f-0d86-4d01-887c-8c0f7a33d7a3',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Confirmed=%{x}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "h", "showlegend": false, "type": "box", "x": [394287, 49660, 0, 596251, 248860, 356110, 205994, 63503, 49, 31107, 736926, 103, 7399, 23704, 148258, 552594, 294762, 244583, 296166, 341431, 28407, 299606, 419721, 559655, 431944, 233665, 473282, 85568, 174614, 243661, 51289, 572692, 153456, 602774, 94438, 125, 762603, 320974, 122847, 708221, 82067, 97614, 344176, 102580, 640606, 301110, 8619, 2143, 387917, 268607, 97898, 544618, 46647], "x0": " ", "xaxis": "x", "y0": " ", "yaxis": "y"}],
#                         {"boxmode": "group", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar ...

# %%
fig2 = px.line(df2_sorted_by_deaths, y='Deaths', x='Province_State', title='Total Deaths by State/Territory as of May 2 2021')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7cfee709-cb5e-4b24-9f36-f3742b69d34a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7cfee709-cb5e-4b24-9f36-f3742b69d34a")) {
#                     Plotly.newPlot(
#                         '7cfee709-cb5e-4b24-9f36-f3742b69d34a',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Province_State=%{x}<br>Deaths=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": ["California", "New York", "Texas", "Florida", "Pennsylvania", "New Jersey", "Illinois", "Georgia", "Ohio", "Michigan", "Massachusetts", "Arizona", "Indiana", "North Carolina", "Tennessee", "Alabama", "Virginia", "Louisiana", "South Carolina", "Missouri", "Maryland", "Connecticut", "Wisconsin", "Minnesota", "Mississippi", "Oklahoma", "Kentucky", "Colorado", "Iowa", "Arkansas", "Washington", "Nevada", "Kansas", "New Mexico", "West Virginia", "Rhode Island", "Oregon", "Puerto Rico", "Nebraska", "Utah", "Idaho", "South Dakota", "Delaware", "Montana", "North Dakota", "New Hampshire", "District of Columbia", "Maine", "Wyoming", "Hawaii", "Alaska", "Vermont", "Guam", "Virgin Islands", "Grand Princess", "Northern Mariana Islands", "Diamond Princess", "American Samoa"], "xaxis": "x", "y": [62078, 52258, 50219, 35161, 26192, 25554, 24291, 20190, 19284, 18753, 17610, 17324, 13332, 12651, 12197, 10896, 10770, 10382, 9497, 9138, 8744, 8097, 7550, 7237, 7199, 6788, 6501, 6295, 5950, 5739, 5499, 5464, 4945, 4067, 2679, 2671, 2495, 2310, 2244, 2202, 2046, 1967, 1625, 1571, 1523, 1303, 1105, 784, 707, 483, 347, 246, 136, 27, 3, 2, 0, 0], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %%
df2_sorted_by_case_fatality = df2.sort_values('Case_Fatality_Ratio', ascending=False)
df2_sorted_by_case_fatality.head(5)
# Out:
#     Province_State Country_Region  ... ISO3   Testing_Rate
# 13  Grand Princess             US  ...  USA            NaN
# 34      New Jersey             US  ...  USA  152610.527359
# 25   Massachusetts             US  ...  USA  308523.057589
# 36        New York             US  ...  USA  262118.174662
# 7      Connecticut             US  ...  USA  224987.245066
#
# [5 rows x 14 columns]

# %%
fig3 = px.scatter(df2_sorted_by_case_fatality, y='Deaths', x='Case_Fatality_Ratio', title='Total Deaths vs. Fatality Ratio by each State/Territory as of May 2 2021')
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b2956f9c-19b7-4d07-965f-6688bcb81523" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b2956f9c-19b7-4d07-965f-6688bcb81523")) {
#                     Plotly.newPlot(
#                         'b2956f9c-19b7-4d07-965f-6688bcb81523',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Case_Fatality_Ratio=%{x}<br>Deaths=%{y}", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scatter", "x": [2.912621359223301, 2.562516107229777, 2.555978245881914, 2.551473280765569, 2.386855052427093, 2.316707549741074, 2.3081115742225067, 2.2725537423559867, 2.263940285358529, 2.0639412640503707, 2.0568139865374016, 2.0085866965334374, 2.0025265172184388, 1.9543988502484348, 1.85057431377312, 1.8351425712174383, 1.8196118970302368, 1.8024644703278312, 1.7919797977345295, 1.7505835278426145, 1.7495167441617467, 1.73532306263321, 1.7321945992556382, 1.7094348052721722, 1.7076845806127574, 1.6589014501157768, 1.6412083800649433, 1.6328325171697569, 1.6308340002850534, 1.603619761943584, 1.5920798454603993, 1.5742429655816519, 1.5564388678703127, 1.5445281481719364, 1.5141477342434282, 1.4637704980782524, 1.4437082441162683, 1.4392929209492231, 1.4268411568343624, 1.4171001088645518, 1.3732268195518833, 1.3643807066296152, 1.3500205614354046, 1.3045603412006368, 1.2807736918628396, 1.2568338277076545, 1.2319802100335444, 1.2159884420900553, 1.1904761904761905, 1.1431599666893784, 1.090292876326896, 1.0718020216103172, 1.0208073658256984, 0.8640000000000001, 0.5542090440271518, 0.5091858895345425, 0.0, null], "xaxis": "x", "y": [3, 25554, 17610, 52258, 8097, 1105, 7199, 26192, 10382, 10896, 4067, 17324, 18753, 8744, 13332, 20190, 24291, 2671, 19284, 2310, 2679, 50219, 5464, 5739, 136, 62078, 9497, 10770, 5950, 1967, 4945, 35161, 1625, 9138, 6788, 6501, 1571, 12197, 483, 1523, 1303, 5499, 2495, 12651, 784, 7237, 6295, 707, 2, 7550, 2046, 246, 2244, 27, 2202, 347, 0, 0], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %%
US_deaths_over_time = pd.read_csv('https://github.com/erisaf2/BDI-Final-Project/blob/main/time_series_covid19_deaths_US.csv?raw=true')
US_deaths_over_time.head(3)
# Out:
#         UID iso2 iso3  code3    FIPS  ... 4/28/21 4/29/21 4/30/21  5/1/21  5/2/21
# 0  84001001   US  USA    840  1001.0  ...     107     107     107     107     107
# 1  84001003   US  USA    840  1003.0  ...     305     305     305     306     306
# 2  84001005   US  USA    840  1005.0  ...      56      56      56      56      56
#
# [3 rows x 479 columns]

# %%
fig4 = px.pie(
    US_deaths_over_time,
    names='Province_State',
    title='Death Breakdown by State as of May 2 2021',
    width=800,
    height=700
)

fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="51ab51b1-7885-454a-9966-b3f68aecf97f" class="plotly-graph-div" style="height:700px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("51ab51b1-7885-454a-9966-b3f68aecf97f")) {
#                     Plotly.newPlot(
#                         '51ab51b1-7885-454a-9966-b3f68aecf97f',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "Province_State=%{label}", "labels": ["Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alabama", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "Alaska", "American Samoa", "Arizona", "Arizona", "Arizona", "Arizona", "Arizona", "Arizona", "Arizona", "Arizona", "Arizona", "Arizona", "Arizona", "Arizona", "Arizona", "Arizona", "Arizona", "Arizona", "Arizona", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "Arkansas", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "Colorado", "C ...

# %%
us_cases_over_time = pd.read_csv('https://github.com/erisaf2/BDI-Final-Project/blob/main/time_series_covid19_confirmed_US.csv?raw=true')
us_cases_over_time.head(3)
# Out:
#         UID iso2 iso3  code3    FIPS  ... 4/28/21 4/29/21 4/30/21  5/1/21  5/2/21
# 0  84001001   US  USA    840  1001.0  ...    6890    6897    6904    6907    6909
# 1  84001003   US  USA    840  1003.0  ...   20897   20921   20941   20966   20983
# 2  84001005   US  USA    840  1005.0  ...    2298    2299    2300    2302    2302
#
# [3 rows x 478 columns]

# %%
us_cases_over_time.drop(columns=['code3','FIPS'], inplace=True)
us_cases_over_time.rename(columns={'Admin2': 'County'}, inplace=True)

# %%
us_cases_over_time.sample(5)
# Out:
#            UID iso2 iso3      County  ... 4/29/21 4/30/21  5/1/21  5/2/21
# 679   84017105   US  USA  Livingston  ...    4697    4720    4731    4738
# 920   84019187   US  USA     Webster  ...    5098    5101    5102    5103
# 2536  84046005   US  USA      Beadle  ...    2932    2933    2933    2933
# 33    84001067   US  USA       Henry  ...    1879    1883    1884    1884
# 3263  84055041   US  USA      Forest  ...    1031    1032    1034    1034
#
# [5 rows x 476 columns]

# %%
fig5 = px.treemap(
    us_cases_over_time,
    path=['Province_State', 'County'],
    title='Top 20 neighbourhoods breakdown',
    values='UID',
    height=700
)

fig5.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-fb97841a0319> in <module>()
#       4     title='Top 20 neighbourhoods breakdown',
#       5     values='UID',
# ----> 6     height=700
#       7 )
#       8
#
# TypeError: treemap() got an unexpected keyword argument 'path'
